# %%
import math as math
import random
import numpy as np
import turtle as turtle

# %%
n = 1000
d = 6
l = 4.5

# myPen = turtle.Turtle()
# myPen.hideTurtle()
# myPen.speed(0)
# count = 0

# #buat garis
# for i in range(0,10):
#   myPen.penup()
#   myPen.goto(-200,y)
#   myPen.pendown()
#   myPen.goto(200,y)
#   y-=boardWidth
# #Draw Needles
# myPen.color("#f442d1")
# for needle in range(0,n):
#   x=random.randint(-180,180)
#   y=random.randint(-180,180)
#   angle=random.randint(0,90)
#   myPen.penup()
#   myPen.goto(x,y)
#   myPen.setheading(angle)
#   myPen.pendown()
#   myPen.forward(l)
#   ran_d = random.uniform(0,d)
#   x = ran_d
  
#   if (x < l * math.cos(angle)) :
#     count+=1


count = 0
i = 1

while i <= n :
  ran_deg = random.uniform(0,90)
  deg = math.radians(ran_deg)
  ran_d = random.uniform(0,d)
  x = ran_d
  
  if (x < l * math.cos(deg)) :
    count+=1
  i+=1

phi = (2 * l / d) * (n / count)
print(phi)
# Out:
# 3.171247357293869
